# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_excel("Data_Science_Fields_Salary_Categorization.xlsx")
df.head()
# Out:
#    Unnamed: 0  Working_Year                 Designation Experience  \
# 0           1          2020              Data Scientist         MI
# 1           2          2020  Machine Learning Scientist         SE
# 2           3          2020           Big Data Engineer         SE
# 3           4          2020        Product Data Analyst         MI
# 4           5          2020   Machine Learning Engineer         SE
#
#   Employment_Status  Salary_In_Rupees Employee_Location Company_Location  \
# 0                FT           6352272                DE               DE
# 1                FT          20688070                JP               JP
# 2                FT           8674985                GB               GB
# 3                FT           1591390                HN               HN
# 4                FT          11935425                US               US
#
#   Company_Size  Remote_Working_Ratio
# 0            L                     0
# 1            S                     0
# ...

# %%
print(df.shape)
# Out:
# (607, 10)

# %%
Experience = df.Experience
Experience.head()
# Out:
# 0    MI
# 1    SE
# 2    SE
# 3    MI
# 4    SE
# Name: Experience, dtype: object

# %%
Company_Size = df.Company_Size
Company_Size.head()
# Out:
# 0    L
# 1    S
# 2    M
# 3    S
# 4    L
# Name: Company_Size, dtype: object

# %%
plt.plot(Experience,Company_Size)

# %%
xtitle = 'Designation'
xtitle = 'Company_Size'

# %%
labels = Designation
sizes = Company_Size

# %%
df_continents = df.groupby('Designation' , axis=0).sum()
print(type(df.groupby('Designation', axis=0)))
df_continents.head()
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
#                                     Unnamed: 0  Working_Year  \
# Designation
# 3D Computer Vision Researcher               78          2021
# AI Scientist                              1786         14148
# Analytics Engineer                        1837          8088
# Applied Data Scientist                    1763         10108
# Applied Machine Learning Scientist        1288          8086
#
#                                     Salary_In_Rupees  Remote_Working_Ratio
# Designation
# 3D Computer Vision Researcher                 430391                    50
# AI Scientist                                36836621                   550
# Analytics Engineer                          55698651                   200
# Applied Data Scientist                      69883904                   350
# Applied Machine Learning Scientist          45217359                   350

# %%
df_continents['Working_Year'].plot(kind='pie', 
                                figsize = (60,70),
                                autopct = '%2.1f%%',
                                startangle = 180,
                                shadow = True,)
plt.title('Salary_In_Rupees Rates overviw 2020 to 2022')

plt.show()
